# %% [markdown]
# # Primera Entrega

# %%
import pandas as pd
import matplotlib as mpl #para graficar por python
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %% [markdown]
# # Lectura del DataSet

# %%
df = pd.read_csv("C:\\Users\\VICTUS\\Documents\\2024\\DATA SCIENCE\\Entregable\\Spotify_Youtube.csv")

# %%
df.tail()
# Out:
#        Unnamed: 0       Artist  \
# 20713       20713  SICK LEGEND
# 20714       20714  SICK LEGEND
# 20715       20715  SICK LEGEND
# 20716       20716  SICK LEGEND
# 20717       20717  SICK LEGEND
#
#                                              Url_spotify  \
# 20713  https://open.spotify.com/artist/3EYY5FwDkHEYLw...
# 20714  https://open.spotify.com/artist/3EYY5FwDkHEYLw...
# 20715  https://open.spotify.com/artist/3EYY5FwDkHEYLw...
# 20716  https://open.spotify.com/artist/3EYY5FwDkHEYLw...
# 20717  https://open.spotify.com/artist/3EYY5FwDkHEYLw...
#
#                                 Track                           Album  \
# 20713            JUST DANCE HARDSTYLE            JUST DANCE HARDSTYLE
# 20714  SET FIRE TO THE RAIN HARDSTYLE  SET FIRE TO THE RAIN HARDSTYLE
# 20715       OUTSIDE HARDSTYLE SPED UP       OUTSIDE HARDSTYLE SPED UP
# 20716             ONLY GIRL HARDSTYLE             ONLY GIRL HARDSTYLE
# 20717              MISS YOU HARDSTYLE              MISS YOU HARDSTYLE
#
# ...

# %% [markdown]
# ELIMINACIÓN DE UNA VARIABLE --> no aporta ningun tipo de información (Unnamed: 0)

# %%
df.drop('Unnamed: 0', axis=1, inplace=True)

# %% [markdown]
# # Información del dataset

# %% [markdown]
# - Estadísticas de musica de youtube incluyendo el numero de streams
# - Número de visualizaciones del video official de la cancion en youtube

# %% [markdown]
# TAMAÑO DEL DATASET

# %%
df.shape
# Out:
# (20718, 27)

# %% [markdown]
# VARIABLES DEL DATASET

# %%
df.columns
# Out:
# Index(['Artist', 'Url_spotify', 'Track', 'Album', 'Album_type', 'Uri',
#        'Danceability', 'Energy', 'Key', 'Loudness', 'Speechiness',
#        'Acousticness', 'Instrumentalness', 'Liveness', 'Valence', 'Tempo',
#        'Duration_ms', 'Url_youtube', 'Title', 'Channel', 'Views', 'Likes',
#        'Comments', 'Description', 'Licensed', 'official_video', 'Stream'],
#       dtype='object')

# %% [markdown]
# METADATA

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20718 entries, 0 to 20717
# Data columns (total 27 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Artist            20718 non-null  object
#  1   Url_spotify       20718 non-null  object
#  2   Track             20718 non-null  object
#  3   Album             20718 non-null  object
#  4   Album_type        20718 non-null  object
#  5   Uri               20718 non-null  object
#  6   Danceability      20716 non-null  float64
#  7   Energy            20716 non-null  float64
#  8   Key               20716 non-null  float64
#  9   Loudness          20716 non-null  float64
#  10  Speechiness       20716 non-null  float64
#  11  Acousticness      20716 non-null  float64
#  12  Instrumentalness  20716 non-null  float64
#  13  Liveness          20716 non-null  float64
#  14  Valence           20716 non-null  float64
#  15  Tempo             20716 non-null  float64
# ...

# %% [markdown]
# Tambien podemos observar cuales son las variables categoricas y cuales las numéricas

# %% [markdown]
# VARIABLES CATEGÓRICAS --> object
# - Artist: Nombre del artista
# - Url_spotify: Url del artista
# - Track: Nombre de la canción, como esta contenida en Spotify
# - Album: Album que contiene la canción
# - Album_type: Tipo de album, solista o compilado
# - Uri: Link de Spotify para encontrar la canción en la API
# - Url_youtube: Url del video de la cancion en Youtube
# - Title: Titulo del video en Youtube
# - Channel: Nombre del canal que publicó el video
# - official_video: Variable booleana que indica si el video es oficial
# - Description: Descripción del video en Youtube
# - Licensed: Indica si el video tiene licencia
#
#
# VARIABLES NUMÉRICAS --> float64 --> considero que estas son las variables de mayor relevancia
# - Danceability: Describe que tan adecuada es la cancion para ser bailada
# - Energy: Representa una medida de la intensidad y actividad
# - Key: La clave en la que se encuentra la pista
# - Loudness: El volumen general de la pista en decibeles (dB)
# - Speechiness: Detecta la presencia de palabras habladas en la pista
# - Acousticness: Una medida de confianza para saber si la pista es acustica
# - Instrumentalness: Indica si una pista no contiene voces
# - Liveness: Detecta la presencia de una audiencia en la grabación
# - Valence: Describe la positividad musical que transmite una pista
# - Tempo: El tempo general estimado en pulsaciones por minuto (BPM)
# - Duration_ms: Duración de la canción en milisegundos
# - Views: Visualizaciones en Youtube
# - Likes: Likes en Youtube
# - Comments: Comentarios en Youtube
# - Stream: Número de reproducciones de la canción en Spotify

# %% [markdown]
# ESTADÍSTICAS EN LOS DATOS

# %%
df.describe() #no incluye las columnas string
# Out:
#        Danceability        Energy           Key      Loudness   Speechiness  \
# count  20716.000000  20716.000000  20716.000000  20716.000000  20716.000000
# mean       0.619777      0.635250      5.300348     -7.671680      0.096456
# std        0.165272      0.214147      3.576449      4.632749      0.111960
# min        0.000000      0.000020      0.000000    -46.251000      0.000000
# 25%        0.518000      0.507000      2.000000     -8.858000      0.035700
# 50%        0.637000      0.666000      5.000000     -6.536000      0.050500
# 75%        0.740250      0.798000      8.000000     -4.931000      0.103000
# max        0.975000      1.000000     11.000000      0.920000      0.964000
#
#        Acousticness  Instrumentalness      Liveness       Valence  \
# count  20716.000000      20716.000000  20716.000000  20716.000000
# mean       0.291535          0.055962      0.193521      0.529853
# std        0.286299          0.193262      0.168531      0.245441
# ...

# %% [markdown]
# # Identificación de Valores Perdidos

# %% [markdown]
# Al observar los datos que nos ofrece df.into() tambien podemos darnos cuenta que hay datos faltantes en algunas columnas

# %% [markdown]
# SUMA DE NULOS

# %%
df.isnull().sum() #para cada columna, indico cuantos datos nulos Nan tiene
# Out:
# Artist                0
# Url_spotify           0
# Track                 0
# Album                 0
# Album_type            0
# Uri                   0
# Danceability          2
# Energy                2
# Key                   2
# Loudness              2
# Speechiness           2
# Acousticness          2
# Instrumentalness      2
# Liveness              2
# Valence               2
# Tempo                 2
# Duration_ms           2
# Url_youtube         470
# Title               470
# Channel             470
# Views               470
# Likes               541
# Comments            569
# Description         876
# Licensed            470
# official_video      470
# Stream              576
# dtype: int64

# %%
null_counts = df.isnull().sum()
plt.figure(figsize=(40, 8))
sns.barplot(x=null_counts.index, y=null_counts.values)
plt.xlabel('Columns')
plt.ylabel('Number of Nan')
plt.title('Nan Values')
plt.show()

# %% [markdown]
# # Visualizaciones

# %% [markdown]
# ### 1. Hay relación entre alguna caracteristica musical y la popularidad?

# %% [markdown]
# RELACION ENTRE LA ACÚSTICA DE LA CANCION Y LA CANTIDAD DE VISUALIZACIONES

# %% [markdown]
# - Grafico de Dispersión con Bokeh

# %%
from bokeh.palettes import Spectral6
from bokeh.models import HoverTool
from bokeh.io import show, output_notebook
output_notebook()
from bokeh.embed import file_html
from bokeh.models import CategoricalColorMapper, ColumnDataSource, FactorRange
from bokeh.plotting import figure, output_file
# Out:
# <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="ee09cbe5-234b-4196-9cc2-d6dd2a945fcf">Loading BokehJS ...</span>
#     </div>

# %%
# Seleccion de datos
from bokeh.models import Range1d
x_scatter = df['Acousticness']# Data en x
y_scatter = df['Views'] # data en y

scatter_plot = figure(width=700, height=300, x_axis_label='Acousticness', y_axis_label='Views', title='Acousticness vs Views') # Grafico (Fondo)
scatter_plot.circle(x_scatter, y_scatter, size=5, line_color='navy', fill_color='orange', fill_alpha=0.5) # Scatter plot
scatter_plot.add_tools(HoverTool()) # Agrego opcion interactiva
scatter_plot.y_range= Range1d(7400, 8800) # Definir limites
scatter_plot.grid.visible= False


show(scatter_plot)
# Out:
#   <div id="f81b7ef4-1efb-4480-bffb-f5db58860881" data-root-id="p1001" style="display: contents;"></div>

# %% [markdown]
# Podemos observar que los datos no tienen una relacion entre si, es decir que la acustica no esta linealmente relacionada con la cantidad de visualizaciones

# %% [markdown]
# RELACIÓN ENTRE LA DURACIÓN DE LA CANCIÓN Y LA CANTIDAD DE VISUALIZACIONES

# %% [markdown]
# - Gráfico de puntos o de dispersion con MatPlotLib

# %%
fig, ax = plt.subplots()
mapeo_colores = ax.scatter(df['Duration_ms'], df['Views'], c=df.index) 

fig.colorbar(mapeo_colores)
ax.set_title('Duration vs Views')
ax.set_xlabel('Duration (ms)')
ax.set_ylabel('Views')

ax.grid(False)

# %% [markdown]
# Podemos observar que la duración y la cantidad de visualizaciones no tienen una relacion lineal positiva, sino que identificamos puntos que se distribuyen al azar sin un patron obvio (falta de dependencia entre los valores)

# %% [markdown]
# ### 2. Hay relacion entre likes, comentarios y visualizaciones?

# %% [markdown]
# - Gráfico de puntos o de dispersión con SeaBorn

# %%
f, axs = plt.subplots(1, 3, figsize=(15, 6), gridspec_kw=dict(width_ratios=[3, 3, 3])) # seteo el lienzo

sns.scatterplot(data=df, x='Views', y='Comments', hue='Album_type', ax=axs[0])
axs[0].set_title('Views vs Comments')
sns.scatterplot(data=df, x='Views', y='Likes', hue='Album_type', ax=axs[1])
axs[1].set_title('Views vs Likes')
sns.scatterplot(data=df, x='Comments', y='Likes', hue='Album_type', ax=axs[2])
axs[2].set_title('Comments vs Likes')
f.tight_layout()

# %% [markdown]
# Podemos observar que estas variables estan intimamente relacionadas, al haber mas visualizaciones hay mas likes y comentarios, el segundo grafico es el que se observa con mayor claridad

# %% [markdown]
# Grafico que incluye las tres variables a relacionar: LIKES, COMENTARIOS, VISUALIZACIONES

# %% [markdown]
# Estan super relacionadas estas tres variables, al aumentar las visualizaciones, aumentan los likes y los comentarios

# %% [markdown]
# VIEWS, LIKES Y COMENTARIOS

# %%
ax = sns.scatterplot(data=df, x='Views', y='Comments', hue='Likes')
ax.grid(False)
ax.set_title('Views, Comments, Likes')
# Out:
# Text(0.5, 1.0, 'Views, Comments, Likes')

# %% [markdown]
# Aca podemos ver que al subir las visualizaciones, aumentan los comentarios y a su vez la cantidad de likes se ve que gradualmente empieza a subir

# %% [markdown]
# ### 3. Influye el tipo de album en la popularidad?

# %% [markdown]
# - Grafico de Barras con MatPlotLib

# %%
fig, ax = plt.subplots(figsize=(8,4))

ax.bar(df['Album_type'], df['Views'])
ax.set_title('Views by album type')
ax.set_xlabel('Album type')
ax.set_ylabel('Views')
ax.grid(False)

# %% [markdown]
# Podemos observar que el tipo de album solista tiene mayor cantidad de visualizaciones que los compilados

# %% [markdown]
# ### 4. Influye la licencia en la popularidad?

# %% [markdown]
# - GRÁFICO DE BARRAS CON SEABORN

# %%
plt.figure(figsize=(5,5))
sns.barplot(y='Views', x= 'Licensed', data=df, palette='Set2')
plt.title('Views vs Licensed')
# Out:
# Text(0.5, 1.0, 'Views vs Licensed')

# %% [markdown]
# Podemos observar que las canciones que presentan un video que tiene licencia, tienen muchas mas visualizaciones

# %% [markdown]
# RELACIÓN ENTRE LICENCIA, VISUALIZACIONES Y TIPO DE ALBUM

# %%
plt.figure(figsize=(5,5))
sns.barplot(y='Views', x= 'Licensed', hue='Album_type', data=df, palette='Set1')
plt.title('License vs Views')
# Out:
# Text(0.5, 1.0, 'License vs Views')

# %% [markdown]
# Como habiamos visto en el anterior gráfico las canciones que tienen un video con licencia tienen más visualizaciones. Además, ahora este grafico nos da informacion sobre como se relacionan esos datos con el tipo de album, en las que tienen licencia son los compilados tienen mas visualizacones, y en las que no, las canciones solistas son las mas vistas

# %% [markdown]
# ### 5. Impacta la existencia de un video oficial en las visualizaciones?

# %% [markdown]
# - GRAFICO DE BARRAS CON SEABORN

# %%
plt.figure(figsize=(5,5))
ax = sns.barplot(y='Views', x= 'official_video', data=df, palette='Set1')
plt.title('Views vs Official Video')
ax.grid(False)

# %% [markdown]
# Podemos observar claramente que cuando hay un video oficial, las visualizaciones aumentan

# %% [markdown]
# ### 6. Como es la distribución de mis datos?

# %% [markdown]
# - DISTRIBUCIÓN DE LA DURACION, HISTOGRAMA CON BOKEH

# %%
data = df['Duration_ms']
data=data[~np.isnan(data)]
hist, edges = np.histogram(data, density=True, bins=40)
p = figure(height=400,width=400, title='Distribution of Duration')
p.quad(top=hist, bottom=0, left=edges[:-1], right=edges[1:], line_color="white", fill_color='orange')
p.xaxis.axis_label = "Duration"
p.yaxis.axis_label = "Frecuency"
p.xgrid.grid_line_color = None
p.ygrid.grid_line_color = None
p.add_tools(HoverTool())
show(p)
# Out:
#   <div id="a3d42416-0e40-4a95-b066-9b1598b6692e" data-root-id="p1085" style="display: contents;"></div>

# %% [markdown]
# La distribucion esta sesgada hacia la derecha, con un pico en torno a las duraciones mas cortas

# %% [markdown]
# - DISTRIBUCION DE LA ACÚSTICA, HISTOGRAMA CON SEABORN

# %%
ax = sns.histplot(data=df, x = 'Acousticness', hue='Album_type')
plt.title('Distribution of Acousticness')
ax.grid(False)

# %% [markdown]
# La distribución parece bastante uniforme, con pico en los valores mas bajos. Hay una proporción mas alta de canciones con mayor acústica

# %% [markdown]
# - DISTRIBUCIÓN DE LA VALENCIA EN LAS CANCIONES, HISTOGRAMA CON SEABORN

# %%
sns.histplot(data=df, x = 'Valence', hue='Album_type', palette='Set1')
plt.title('Distribution of Valence')
# Out:
# Text(0.5, 1.0, 'Distribution of Valence')

# %% [markdown]
# La distribución parece bastante simetrica, vemos que hay tanto canciones con tonos emocionales positivos como negativos

# %% [markdown]
# - DISTRIBUCIÓN DEL TEMPO, BOXPLOT CON SEABORN

# %%
sns.set_theme(style="whitegrid")
ax = sns.boxplot(x=df['Tempo'], palette='Set1')
ax.grid(False)
ax.set_title('Distribution of Tempo')
plt.show()

# %% [markdown]
# Esta distribucion parece ser aproximadamente normal. La mayoria de las canciones tienen tiempos moderados, pero hay valores atipicos muy grandes o muy chicos

# %%
plt.figure(figsize=(10, 6))
sns.violinplot(x='official_video', y='Danceability', data=df)
plt.title('Distribution of Speechiness between Official and Non-Official Videos', fontsize=16)
plt.xlabel('Official Video', fontsize=14)
plt.ylabel('Speechiness', fontsize=14)
# Out:
# Text(0, 0.5, 'Speechiness')
